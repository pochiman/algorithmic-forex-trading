# %%
import sys
sys.path.append("../")
import pandas as pd
import plotly.graph_objects as go
import datetime as dt
from plotting import CandlePlot

# %%
from infrastructure.instrument_collection import instrumentCollection as ic

# %%
pair = "GBP_JPY"
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")
MA_LIST = [10, 20, 50, 100, 200]

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c
# 0 2021-05-24 09:00:00+00:00  153.991  154.105  153.776  154.035
# 1 2021-05-24 13:00:00+00:00  154.032  154.108  153.866  154.016
# 2 2021-05-24 17:00:00+00:00  154.014  154.034  153.939  153.974
# 3 2021-05-24 21:00:00+00:00  153.902  154.152  153.902  154.120
# 4 2021-05-25 01:00:00+00:00  154.118  154.220  154.017  154.162

# %%
for ma in MA_LIST:
    df_ma[f'MA_{ma}'] = df_ma.mid_c.rolling(window=ma).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)

# %%
df_plot = df_ma.iloc[:500]

# %%
cp = CandlePlot(df_plot)

# %%
traces = [ f"MA_{x}" for x in MA_LIST ]

# %%
cp.show_plot(line_traces=traces)

# %%
MA_S = "MA_50"
MA_L = "MA_200"
BUY = 1
SELL = -1
NONE = 0

# %%
df_an = df_ma[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c', MA_S, MA_L]].copy()

# %%
df_an.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 0 2021-07-08 13:00:00+00:00  150.923  151.277  150.722  151.231  153.13558
# 1 2021-07-08 17:00:00+00:00  151.229  151.388  151.130  151.329  153.08012
# 2 2021-07-08 21:00:00+00:00  151.251  151.560  151.189  151.494  153.04010
# 3 2021-07-09 01:00:00+00:00  151.490  151.541  151.178  151.514  152.99950
# 4 2021-07-09 05:00:00+00:00  151.512  151.782  151.446  151.686  152.96854
#
#        MA_200
# 0  154.276245
# 1  154.262715
# 2  154.250105
# 3  154.237805
# 4  154.225635

# %%
df_an['DELTA'] = df_an.MA_50 - df_an.MA_200
df_an['DELTA_PREV'] = df_an.DELTA.shift(1)

# %%
def is_trade(row):
    if row.DELTA >= 0 and row.DELTA_PREV < 0:
        return BUY
    elif row.DELTA < 0 and row.DELTA_PREV >= 0:
        return SELL
    return NONE

# %%
df_an['TRADE'] = df_an.apply(is_trade, axis=1)

# %%
df_trades = df_an[df_an.TRADE != NONE].copy()

# %%
df_trades.head()
# Out:
#                          time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 134 2021-08-09 21:00:00+00:00  152.768  152.905  152.712  152.815  152.50896
# 176 2021-08-18 21:00:00+00:00  150.986  151.139  150.946  151.051  152.14970
# 271 2021-09-09 17:00:00+00:00  152.015  152.021  151.750  151.828  151.77846
# 313 2021-09-20 17:00:00+00:00  149.270  149.544  149.182  149.402  151.57646
# 402 2021-10-11 13:00:00+00:00  154.175  154.512  154.029  154.352  151.38858
#
#          MA_200     DELTA  DELTA_PREV  TRADE
# 134  152.508625  0.000335   -0.010650      1
# 176  152.150745 -0.001045    0.023490     -1
# 271  151.777910  0.000550   -0.015855      1
# 313  151.599845 -0.023385    0.012675     -1
# 402  151.356965  0.031615   -0.030855      1

# %%
cp = CandlePlot(df_an.iloc[220:260])
cp.show_plot(line_traces=[MA_S, MA_L])

# %%
ic.LoadInstruments("../data")

# %%
ic.instruments_dict[pair]
# Out:
# {'name': 'GBP_JPY', 'ins_type': 'CURRENCY', 'displayName': 'GBP/JPY', 'pipLocation': 0.01, 'tradeUnitsPrecision': 0, 'marginRate': 0.06}

# %%
ins_data = ic.instruments_dict[pair]

# %%
df_trades.shape
# Out:
# (32, 10)

# %%
df_trades['DIFF'] = df_trades.mid_c.diff().shift(-1)
df_trades.fillna(0, inplace=True)

# %%
df_trades['GAIN'] = df_trades['DIFF'] / ins_data.pipLocation
df_trades['GAIN'] = df_trades['GAIN'] * df_trades['TRADE']

# %%
df_trades.GAIN.sum()
# Out:
# -6658.800000000008

# %%
df_trades['GAIN_C'] = df_trades['GAIN'].cumsum()

# %%
cp = CandlePlot(df_trades, candles=False)
cp.show_plot(line_traces=['GAIN_C'])
